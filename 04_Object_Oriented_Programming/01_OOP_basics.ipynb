# %%
lst = [1,2,3]

# %%
lst.append(4)

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.pop()
# Out:
# 4

# %%
lst.append(3)

# %%
lst
# Out:
# [1, 2, 3, 3]

# %%
lst.count(3)
# Out:
# 2

# %% [markdown]
# #### Objects

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
print(type([]))
# Out:
# <class 'list'>

# %%
print(type(()))
# Out:
# <class 'tuple'>

# %%
print(type({}))
# Out:
# <class 'dict'>

# %% [markdown]
# #### Class

# %%
class Sample:
    pass

# %%
x = Sample() #Creating an INSTANCE of class Sample or Instantiate the class with variable x

# %%
print(type(x))
# Out:
# <class '__main__.Sample'>

# %% [markdown]
# #### Attribute
#
# * A characteristic of an object

# %%
class Dog:
    def __init__(self,breed):
        self.breed = breed

# %% [markdown]
# * In above example:
#
# 1. __init__ : special method that is called right after the object is created
# 2. def __init__(self,breed): breed is the argument whose value needs to be passed during the class instantiation

# %%
dog1 = Dog(breed = 'Lab')

# %%
dog1.breed
# Out:
# 'Lab'

# %%
dog2 = Dog(breed='Huskie')

# %%
dog2.breed
# Out:
# 'Huskie'

# %%
class Dog:
    def __init__(self,breed,name,color):
        self.name = name
        self.breed = breed
        self.color = color

# %%
dog3 = Dog(breed='Lab',name='Jackie',color='black')

# %%
dog3.name
# Out:
# 'Jackie'

# %%
dog3.color
# Out:
# 'black'

# %%
dog3.breed
# Out:
# 'Lab'

# %% [markdown]
# ###### Class object Attributes
#
# * They remain same for any instance of the class

# %%
class Dog:
    species = 'mammal' #class object attribute
    
    def __init__(self,breed,name): #constructor
        self.breed = breed
        self.name = name

# %%
another_dog = Dog(breed='Huskie',name='Sam')

# %%
another_dog.species
# Out:
# 'mammal'

# %% [markdown]
# ### Methods
#
# * Functions defined inside the body of a class.
# * Used to perform opertaios with the attributes of our objects.

# %%
class Circle:
    
    pi = 3.14 #Class Object Attribute
    
    def __init__(self,radius=1):
        self.radius = radius
        self.area = radius * radius * Circle.pi
        self.circumference = radius*Circle.pi*2
        
    #Method for resetting Radius
    def setRadius(self,new_radius):
        self.radius = new_radius
        self.area = new_radius * new_radius * self.pi # or Circle.pi
        
    #Method for getting circumference
    def getCircumference(self):
        return self.radius*self.pi*2

# %%
c = Circle(radius=20)

# %%
c.radius
# Out:
# 20

# %%
c.pi
# Out:
# 3.14

# %%
c.area
# Out:
# 1256.0

# %%
c1 = Circle(radius=2)

# %%
c1.area
# Out:
# 12.56

# %%
c1.radius
# Out:
# 2

# %%
c1.pi
# Out:
# 3.14

# %%
c1.setRadius(new_radius=4)

# %%
c1.area
# Out:
# 50.24

# %%
c1.radius
# Out:
# 4

# %%
c1.pi
# Out:
# 3.14

# %%
c2 = Circle(radius=9)

# %%
c2.radius
# Out:
# 9

# %%
c2.area
# Out:
# 254.34

# %%
c2.getCircumference()
# Out:
# 56.52

# %%
c2.setRadius(new_radius=10)

# %%
c2.getCircumference()
# Out:
# 62.800000000000004

# %%
c2.circumference
# Out:
# 56.52

# %%
c2.getCircumference()
# Out:
# 62.800000000000004

# %% [markdown]
# ###### Example 1 : Create Line class methods to accept coordinates as a pair of tuples  and return the slope and distance of the line

# %%
class Line:
    
    def __init__(self,coor1,coor2):
        self.coor1 = coor1
        self.coor2 = coor2
        
    def distance(self):
        x1,y1 = self.coor1
        x2,y2 = self.coor2
        return ((x2-x1)**2)+((y2-y1)**2)**0.5
    
    def slope(self):
        x1,y1 = self.coor1
        x2,y2 = self.coor2
        return (y2-y1)/(x2-x1)

# %%
co1 = (3,4)
co2 = (10,12)

li = Line(coor1=co1,coor2=co2)

# %%
li.coor1
# Out:
# (3, 4)

# %%
li.coor2
# Out:
# (10, 12)

# %%
li.distance()
# Out:
# 57.0

# %%
li.slope()
# Out:
# 1.1428571428571428
