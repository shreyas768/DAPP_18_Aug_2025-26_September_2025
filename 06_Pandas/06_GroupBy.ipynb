# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df['origin'].unique()
# Out:
# array([1, 3, 2])

# %%
#1 : USA
#2 : Europe
#3 : Japan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df['horsepower'].sum()
# Out:
# '13016515015014019822021522519017016015022595959785884687909511390215200210193889095?1001051008810016517515315018017017511072100888690707665696070958054908616517515015315020815516019097150130140150112768769869297808817515014513715019815015815021522517510510010088954615016717018010088729490851079014523049759111215011012218095?...?676213210088?72848492110845864606765626863656574?7575100748076116120110105888588888885849092?746868637088757067676711085921129684908652847982'

# %%
df['horsepower'].apply(lambda x : int(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df['horsepower'].apply(lambda x : int(x))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# ...

# %%
#method 1

df['horsepower'].replace('?','O')
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 393     86
# 394     52
# 395     84
# 396     79
# 397     82
# Name: horsepower, Length: 398, dtype: object

# %%
df[df['horsepower']=='?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model_year  origin                  name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
int(df[(df['horsepower'] != '?') & (df['cylinders'] == 4)]['horsepower'].apply(lambda x : int(x)).mean())
# Out:
# 78

# %%
#Method 2


df['horsepower'] = df['horsepower'].replace('?',int((df[(df['horsepower'] != '?') & (df['cylinders'] == 4)][
    'horsepower'].apply(lambda x : int(x))).mean()))

# %%
df['horsepower'] = df['horsepower'].apply(lambda x : int(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 28.1+ KB

# %% [markdown]
# ### GroupBy

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df = df.drop(['origin','name'],axis=1)

# %% [markdown]
# https://tih.iitr.ac.in/training-courseDetails/83
#
# https://tih.iitr.ac.in/training-courseDetails/90

# %%
df.groupby('model_year').max()
# Out:
#              mpg  cylinders  displacement  horsepower  weight  acceleration
# model_year
# 70          27.0          8         455.0         225    4732          20.5
# 71          35.0          8         400.0         180    5140          20.5
# 72          28.0          8         429.0         208    4633          23.5
# 73          29.0          8         455.0         230    4997          21.0
# 74          32.0          8         350.0         150    4699          21.0
# 75          33.0          8         400.0         170    4668          21.0
# 76          33.0          8         351.0         180    4380          22.2
# 77          36.0          8         400.0         190    4335          19.0
# 78          43.1          8         318.0         165    4080          21.5
# 79          37.3          8         360.0         155    4360          24.8
# 80          46.6          6         225.0         132    3381          23.7
# ...

# %%
df.groupby('model_year').mean()
# Out:
#                   mpg  cylinders  displacement  horsepower       weight  \
# model_year
# 70          17.689655   6.758621    281.413793  147.827586  3372.793103
# 71          21.250000   5.571429    209.750000  106.000000  2995.428571
# 72          18.714286   5.821429    218.375000  120.178571  3237.714286
# 73          17.100000   6.375000    256.875000  130.475000  3419.025000
# 74          22.703704   5.259259    171.740741   93.629630  2877.925926
# 75          20.266667   5.600000    205.533333  101.066667  3176.800000
# 76          21.573529   5.647059    197.794118  101.117647  3078.735294
# 77          23.375000   5.464286    191.392857  105.071429  2997.357143
# 78          24.061111   5.361111    177.805556   99.694444  2861.805556
# 79          25.093103   5.827586    206.689655  101.206897  3055.344828
# 80          33.696552   4.137931    115.827586   77.517241  2436.655172
# 81          30.334483   4.620690    135.310345   80.931034  2522.931034
# ...

# %%
df.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %% [markdown]
# ###### Multiple Columns

# %%
df1 = df.groupby(['model_year','cylinders']).mean()
df1
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         4          27.461538    101.846154   77.615385  2056.384615
#            6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
# ...

# %%
df1.columns
# Out:
# Index(['mpg', 'displacement', 'horsepower', 'weight', 'acceleration'], dtype='object')

# %%
df1.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
df1.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
df1.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
df1.loc[(81,6)]
# Out:
# mpg               23.428571
# displacement     184.000000
# horsepower       100.714286
# weight          3093.571429
# acceleration      15.442857
# Name: (81, 6), dtype: float64

# %%
df1.loc[[(81,6),(74,8)]]
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 81         6          23.428571         184.0  100.714286  3093.571429
# 74         8          14.200000         315.2  146.000000  4438.400000
#
#                       acceleration
# model_year cylinders
# 81         6             15.442857
# 74         8             14.700000

# %%
df1.loc[[73,75]]
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
#            8          13.200000    365.250000  170.000000  4279.050000
# 75         4          25.250000    114.833333   84.916667  2489.250000
#            6          17.583333    233.750000   96.750000  3398.333333
#            8          15.666667    330.500000  142.000000  4108.833333
#
#                       acceleration
# model_year cylinders
# 73         3             13.500000
#            4             17.136364
#            6             15.687500
#            8             12.250000
# 75         4             15.833333
#            6             17.708333
#            8             13.166667

# %%
df.groupby('cylinders').agg(
{
    'mpg' : ['median','max','mean','count'],
    'weight' : ['std','min','var'],
    'horsepower' : ['mean','max','sum','count']
})
# Out:
#              mpg                             weight                       \
#           median   max       mean count         std   min            var
# cylinders
# 3          20.25  23.7  20.550000     4  247.566153  2124   61289.000000
# 4          28.25  46.6  29.286765   204  347.093936  1613  120474.200425
# 5          25.40  36.4  27.366667     3  374.343870  2830  140133.333333
# 6          19.00  38.0  19.985714    84  332.297419  2472  110421.574727
# 8          14.00  26.6  14.963107   103  448.833159  3086  201451.204264
#
#            horsepower
#                  mean  max    sum count
# cylinders
# 3           99.250000  110    397     4
# 4           78.274510  115  15968   204
# 5           82.333333  103    247     3
# 6          101.226190  165   8503    84
# 8          158.300971  230  16305   103

# %% [markdown]
# 1. sum
# 2. mean
# 3. size
# 4. count
# 5. std
# 6. var
# 7. describe
# 8. min
# 9. max
# 10. first
# 11. last
