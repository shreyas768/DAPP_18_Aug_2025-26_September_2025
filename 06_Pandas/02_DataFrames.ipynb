# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###### Create a DataFrame from Python Objects

# %%
np.random.seed(101)
mydata = np.random.randint(1,80,(4,3))

# %%
mydata
# Out:
# array([[12, 71, 64],
#        [76, 10, 78],
#        [41,  5, 64],
#        [41, 61, 65]])

# %%
myindex = ['RJ','WB','KL','JK']
mycolumns = ['Jan','Feb','Mar']

# %%
df_unnamed = pd.DataFrame(data=mydata)
df_unnamed
# Out:
#     0   1   2
# 0  12  71  64
# 1  76  10  78
# 2  41   5  64
# 3  41  61  65

# %%
pd.DataFrame(data=mydata,index=myindex)
# Out:
#      0   1   2
# RJ  12  71  64
# WB  76  10  78
# KL  41   5  64
# JK  41  61  65

# %%
df = pd.DataFrame(data=mydata,index =myindex, columns=mycolumns)

# %%
df
# Out:
#     Jan  Feb  Mar
# RJ   12   71   64
# WB   76   10   78
# KL   41    5   64
# JK   41   61   65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, RJ to JK
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df_unnamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      int64
#  1   1       4 non-null      int64
#  2   2       4 non-null      int64
# dtypes: int64(3)
# memory usage: 228.0 bytes

# %% [markdown]
# #### Reading a CSV file for a DataFrame

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ###### Obtaining Basic Information About DataFrame

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(12)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
#
# ...

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.sample(7)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 142       41.19  5.00    Male     No  Thur   Lunch     5              8.24
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 41        17.46  2.54    Male     No   Sun  Dinner     2              8.73
#
#         Payer Name         CC Number Payment ID
# 197    Brooke Soto  5544902205760175   Thur9313
# 85     Shawna Cook  6011787464177340   Thur7972
# 236  Matthew Myers  3543676378973965    Sat5032
# 226     Ruth Weiss  5268689490381635    Fri6359
# 142   Eric Andrews  4356531761046453   Thur3621
# 232   James Taylor  6011482917327995    Sat2124
# ...

# %%
df.shape
# Out:
# (244, 11)

# %%
type(df.shape)
# Out:
# tuple

# %%
len(df)
# Out:
# 244

# %%
df.shape[0]
# Out:
# 244

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df_des = df.describe()
df_des
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
type(df_des)
# Out:
# pandas.core.frame.DataFrame

# %%
df_des.shape
# Out:
# (8, 5)

# %%
df_des.columns
# Out:
# Index(['total_bill', 'tip', 'size', 'price_per_person', 'CC Number'], dtype='object')

# %% [markdown]
# #### Selection and Indexing

# %% [markdown]
# ###### Columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
#Single column

df['price_per_person']
# Out:
# 0       8.49
# 1       3.45
# 2       7.00
# 3      11.84
# 4       6.15
#        ...
# 239     9.68
# 240    13.59
# 241    11.34
# 242     8.91
# 243     9.39
# Name: price_per_person, Length: 244, dtype: float64

# %%
type(df['price_per_person'])
# Out:
# pandas.core.series.Series

# %%
#Grab Multiple Columns

df[['total_bill','tip','Payer Name']]
# Out:
#      total_bill   tip          Payer Name
# 0         16.99  1.01  Christy Cunningham
# 1         10.34  1.66      Douglas Tucker
# 2         21.01  3.50      Travis Walters
# 3         23.68  3.31    Nathaniel Harris
# 4         24.59  3.61        Tonya Carter
# ..          ...   ...                 ...
# 239       29.03  5.92       Michael Avila
# 240       27.18  2.00      Monica Sanders
# 241       22.67  2.00          Keith Wong
# 242       17.82  1.75        Dennis Dixon
# 243       18.78  3.00     Michelle Hardin
#
# [244 rows x 3 columns]

# %%
type(df[['total_bill','tip','Payer Name']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###### Create a New Column

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df['tip_percentage'] = np.round(df['tip']*100/df['total_bill'],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
df['tip_per_person'] = np.round(df['tip']/df['size'],2)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
#
#    tip_per_person
# 0            0.50
# 1            0.55
# 2            1.17

# %%
#Adjust Existing Column
df['tip_per_person'] = np.round(df['tip_per_person'],1)
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
#
#    tip_per_person
# 0             0.5
# 1             0.6
# 2             1.2

# %% [markdown]
# ###### Removing Column(s)

# %%
df = df.drop('tip_percentage',axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_per_person
# ...

# %%
df['tip_percentage'] = np.round(df['tip']*100/df['total_bill'],2)
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID  tip_per_person  \
# 0  Christy Cunningham  3560325168603410    Sun2959             0.5
# 1      Douglas Tucker  4478071379779230    Sun4608             0.6
# 2      Travis Walters  6011812112971322    Sun4458             1.2
#
#    tip_percentage
# 0            5.94
# 1           16.05
# 2           16.66

# %%
df = df.drop(['tip_per_person','tip_percentage'],axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ###### Index Basics

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
#Creating existing column as a Index
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df = df.reset_index()
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
list(df.columns)
# Out:
# ['Payment ID',
#  'total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'price_per_person',
#  'Payer Name',
#  'CC Number']

# %%
df[['total_bill',
 'tip',
 'sex',
 'smoker',
 'day',
 'time',
 'size',
 'price_per_person',
 'Payer Name',
 'CC Number','Payment ID']]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ###### ROWS

# %%
df = df.set_index('Payment ID')
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
#Grab a single row

df.iloc[3] #grabbing based on index location
# Out:
# total_bill                     23.68
# tip                             3.31
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               2
# price_per_person               11.84
# Payer Name          Nathaniel Harris
# CC Number           4676137647685994
# Name: Sun5260, dtype: object

# %%
df.loc['Sun5260'] #based on index name
# Out:
# total_bill                     23.68
# tip                             3.31
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               2
# price_per_person               11.84
# Payer Name          Nathaniel Harris
# CC Number           4676137647685994
# Name: Sun5260, dtype: object

# %%
#Grabbing multiple rows

df.iloc[11:151:3]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun3848          14.83  3.02  Female     No   Sun  Dinner     2
# Sun2998          16.29  3.71    Male     No   Sun  Dinner     3
# Sat1709          17.92  4.08    Male     No   Sat  Dinner     2
# Sat239           39.42  7.58    Male     No   Sat  Dinner     4
# Sat6651          13.37  2.00    Male     No   Sat  Dinner     2
# Sat2467          19.65  3.00  Female     No   Sat  Dinner     2
# Sat1327          15.06  3.00  Female     No   Sat  Dinner     2
# Sat632           24.06  3.60    Male     No   Sat  Dinner     3
# Sat4056          18.69  2.31    Male     No   Sat  Dinner     3
# Sun9460          17.46  2.54    Male     No   Sun  Dinner     2
# Sun2274          30.40  5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40  6.00    Male     No   Sun  Dinner     4
# ...

# %%
df.iloc[0:3]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322

# %%
df.loc[['Thur6321','Thur3906','Sun4458']]
# Out:
#             total_bill  tip     sex smoker   day    time  size  \
# Payment ID
# Thur6321          7.51  2.0    Male     No  Thur   Lunch     2
# Thur3906         17.47  3.5  Female     No  Thur   Lunch     2
# Sun4458          21.01  3.5    Male     No   Sun  Dinner     3
#
#             price_per_person      Payer Name         CC Number
# Payment ID
# Thur6321                3.76  Daniel Robbins  4823139288341889
# Thur3906                8.74      Kayla Rios  5233918213804470
# Sun4458                 7.00  Travis Walters  6011812112971322

# %%
#Remove a row

df.drop('Thur3906')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...
