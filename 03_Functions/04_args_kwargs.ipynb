# %%
def myfunc(a,b):
    return sum((a,b))*0.05

# %%
myfunc(40,60)
# Out:
# 5.0

# %%
def myfunc(a=0,b=0,c=0,d=0,e=0):
    return sum((a,b,c,d,e))*0.05

# %%
myfunc(a=23,b=2,e=12)
# Out:
# 1.85

# %% [markdown]
# ###### *args

# %%
def demo_func(*args):
    return sum(args)*0.05

# %%
demo_func(23,12,3,4,2,3,4,5,3,4,2,24,2)
# Out:
# 4.55

# %% [markdown]
# ###### **kwargs

# %%
def demo_func1(**kwargs):
    if 'fruit' in kwargs:
        print(f"My fav fruit is {kwargs['fruit']}")
    else:
        rpint("I don't like fruit")

# %%
demo_func1(fruit = 'apple')
# Out:
# My fav fruit is apple

# %% [markdown]
# ###### *args and **kwargs combined

# %%
def myfunc(*args,**kwargs):
    if 'fruit' and 'juice' in kwargs:
        print(f"I like {' and '.join(args)}, my fav fruit is {kwargs['fruit']}")
        print(f"May I have some {kwargs['juice']} juice? ")

# %%
myfunc('milk','curd','rice', fruit='mangoes',juice='apple')
# Out:
# I like milk and curd and rice, my fav fruit is mangoes
# May I have some apple juice?
