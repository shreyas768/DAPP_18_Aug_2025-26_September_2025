# %% [markdown]
# ###### Creating a string

# %%
#single word

'hello'
# Out:
# 'hello'

# %%
#Entire phrase

'This is also a string'
# Out:
# 'This is also a string'

# %%
#Use double quote

"String built with double quotes"
# Out:
# 'String built with double quotes'

# %%
"I'm here"
# Out:
# "I'm here"

# %% [markdown]
# ###### Printing a String

# %%
'Hello Universe 1'
'Hello Universe 2'
# Out:
# 'Hello Universe 2'

# %%
print('Hello Universe 1')
print('Hello Universe 2')
print('Hello Universe 3')
print('Use \n to print a new line')
print('Use \t to enter tab')
# Out:
# Hello Universe 1
# Hello Universe 2
# Hello Universe 3
# Use
#  to print a new line
# Use 	 to enter tab

# %% [markdown]
# ###### Basics of string

# %%
len('shreyas')
# Out:
# 7

# %%
len('Hello Universe 1')
# Out:
# 16

# %%
s = 'This is some random string'

# %%
s
# Out:
# 'This is some random string'

# %%
type(s)
# Out:
# str

# %%
len(s)
# Out:
# 26

# %%
type(len)
# Out:
# builtin_function_or_method

# %% [markdown]
# ###### String Indexing

# %%
st = 'Hello India'

# %%
st
# Out:
# 'Hello India'

# %%
print(st)
# Out:
# Hello India

# %%
st[9]
# Out:
# 'i'

# %%
st[-2]
# Out:
# 'i'

# %%
#Slicing

# %%
name = 'Shubman Gill'

# %%
first_name = name[0:7]

# %%
len(name)
# Out:
# 12

# %%
name[-12:-5] #same as name[:-5]
# Out:
# 'Shubman'

# %%
first_name
# Out:
# 'Shubman'

# %%
len(first_name)
# Out:
# 7

# %%
name[8:] #same as name[8:12]
# Out:
# 'Gill'

# %%
name[:7] #same as name[0:7]
# Out:
# 'Shubman'

# %%
name[:]
# Out:
# 'Shubman Gill'

# %%
name[-4:]
# Out:
# 'Gill'

# %%
name[:7:-2]
# Out:
# 'li'

# %%
s = 'programming'

# %%
s[4::-1]
# Out:
# 'rgorp'

# %%
s = 'shreyas'

# %%
s[::-1]
# Out:
# 'sayerhs'

# %%
s = 'Deep Learning'

# %%
s[:-13:-2]
# Out:
# 'gire e'

# %% [markdown]
# ###### String Properties
#
#
# * Immutability: Once a string is created, elements within it cannot be changed

# %%
st = 'Hello world'

# %%
st[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 st[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %%
#Unlike Lists, which are mutable
l1 = [12,34.5,'hi']
l1[0] = 'hello'
l1
# Out:
# ['hello', 34.5, 'hi']

# %%
#Concatenate Strings

st + ' How is it going?'
# Out:
# 'Hello world How is it going?'

# %%
a = 3

# %%
st + a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 st + a
#
# TypeError: can only concatenate str (not "int") to str

# %%
st = st + ' How is it going?'

# %%
st
# Out:
# 'Hello world How is it going?'

# %%
2+7
# Out:
# 9

# %%
'2' + '7'
# Out:
# '27'

# %%
type('2')
# Out:
# str

# %%
print(2+7)
# Out:
# 9

# %%
print('2'+'7')
# Out:
# 27

# %%
'hi'*4 #Multiplication Symbol for repetition
# Out:
# 'hihihihi'

# %% [markdown]
# ###### Basic Built-In String Methods
#
#
# * object.method(parameters)

# %%
s
# Out:
# 'Deep Learning'

# %%
#Upper case a string

s.upper()
# Out:
# 'DEEP LEARNING'

# %%
s.upper
# Out:
# <function str.upper()>

# %%
'Deep learning'.upper()
# Out:
# 'DEEP LEARNING'

# %%
#Lower case

s.lower()
# Out:
# 'deep learning'

# %%
#split: split a string by a blank space(default)

demo_list = s.split()

# %%
s.split('p')
# Out:
# ['Dee', ' Learning']

# %%
type(demo_list)
# Out:
# list

# %%
'This is where I am'.split()
# Out:
# ['This', 'is', 'where', 'I', 'am']

# %%
l2 = 'rbpl.edu@gmail.com'.split('@')
l2
# Out:
# ['rbpl.edu', 'gmail.com']

# %%
x = 'hello world hello'

# %%
#capitalize

x.capitalize()
# Out:
# 'Hello world hello'

# %%
#count
x.count('l')
# Out:
# 5

# %%
x.count('hello')
# Out:
# 2

# %%
x.find('world')
# Out:
# 6

# %% [markdown]
# ###### is check methods

# %%
s = 'deeplearning'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %%
s.isspace() #True if all the characters are whitespace
# Out:
# False

# %%
t = '         '
t.isspace()
# Out:
# True

# %%
2 == 2
# Out:
# True

# %%
'HELLO' == 'hello'.upper()
# Out:
# True

# %%
s
# Out:
# 'deeplearning'

# %%
s[-1] == 'g'
# Out:
# True

# %%
s.endswith('ing')
# Out:
# True

# %%
s[-3:] == 'ing'
# Out:
# True

# %%
s[-3:]
# Out:
# 'ing'
