# %%
my_dict = {'key1':'value1','key2':'value2'}

# %%
my_dict['key2']
# Out:
# 'value2'

# %%
my_dict2 = {'k1': 123,
           'k2':[12,34,'hi','hello',[1,2,3]],
           'k3': {'k_alt':'world',
                 'k_alt2': 'IIT Roorkee'}}

# %%
my_dict2['k2']
# Out:
# [12, 34, 'hi', 'hello', [1, 2, 3]]

# %%
type(my_dict2['k2'])
# Out:
# list

# %%
my_dict2['k2'][-2].upper()
# Out:
# 'HELLO'

# %%
my_dict2['k3']['k_alt'].capitalize()
# Out:
# 'World'

# %%
my_dict2['k2'][-2].upper()+' '+my_dict2['k3']['k_alt'].capitalize()
# Out:
# 'HELLO World'

# %%
my_dict2['k4'] = ['RBPL', 'IIT Guwahati'] #create a new k:v pair in a dictionary

# %%
my_dict2
# Out:
# {'k1': 123,
#  'k2': [12, 34, 'hi', 'hello', [1, 2, 3]],
#  'k3': {'k_alt': 'world', 'k_alt2': 'IIT Roorkee'},
#  'k4': ['RBPL', 'IIT Guwahati']}

# %%
my_dict2['k1'] = 'India'

# %%
my_dict2
# Out:
# {'k1': 'India',
#  'k2': [12, 34, 'hi', 'hello', [1, 2, 3]],
#  'k3': {'k_alt': 'world', 'k_alt2': 'IIT Roorkee'},
#  'k4': ['RBPL', 'IIT Guwahati']}

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d['k1'] = 'value1'

# %%
d
# Out:
# {'k1': 'value1'}

# %% [markdown]
# ###### Dictionary Methods

# %%
d = {'k1':1,'k2':2,'k3':3}

# %%
#Method to return a list of all the keys
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
type(d.keys())
# Out:
# dict_keys

# %%
sample_list = list(d.keys())

# %%
type(sample_list)
# Out:
# list

# %%
int(100.923)
# Out:
# 100

# %%
int('1000')
# Out:
# 1000

# %%
#Method to return a list of all the values
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
my_dict2.values()
# Out:
# dict_values(['India', [12, 34, 'hi', 'hello', [1, 2, 3]], {'k_alt': 'world', 'k_alt2': 'IIT Roorkee'}, ['RBPL', 'IIT Guwahati']])

# %%
#method to return tuples of k:v pair
d.items()
# Out:
# dict_items([('k1', 1), ('k2', 2), ('k3', 3)])
