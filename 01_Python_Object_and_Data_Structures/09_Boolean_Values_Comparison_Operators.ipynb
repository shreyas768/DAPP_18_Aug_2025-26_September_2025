# %% [markdown]
# ###### Equal

# %%
b1 = 2 == 2

# %%
b1
# Out:
# True

# %%
type(b1)
# Out:
# bool

# %%
b2 = 2 != 2

# %%
type(b2)
# Out:
# bool

# %%
b2
# Out:
# False

# %%
'hi' == 'hi'
# Out:
# True

# %%
1 == '1'
# Out:
# False

# %%
'Shreyas'[0] == 's'.upper()
# Out:
# True

# %%
len('Shreyas') == 7
# Out:
# True

# %%
'Shreyas shukla'.split() == ['Shreyas','Shukla']
# Out:
# False

# %%
'Shreyas shukla'.split()
# Out:
# ['Shreyas', 'shukla']

# %% [markdown]
# ###### Greater Than

# %%
2 > 3
# Out:
# False

# %%
2 >1
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %% [markdown]
# ###### Less Than

# %%
2 <= 6
# Out:
# True

# %%
2 < 2
# Out:
# False

# %% [markdown]
# # Chained Comparison Operators (logical operators)

# %%
1 < 2 > 4
# Out:
# False

# %%
#and statement

1 < 2 and 2 < 4
# Out:
# True

# %%
1 < 2 and 2 > 4
# Out:
# False

# %%
len('hi') > 1 and 'Shreyas'[:2] == 'Sh'
# Out:
# True

# %%
'Shreyas'[:2]
# Out:
# 'Sh'

# %%
#or statement

1 == 2 or 2 < 3
# Out:
# True

# %%
1 == 1 or 2 > 3
# Out:
# True

# %%
1 == 1 or 2 < 3
# Out:
# True

# %%
1 == 2 or 2 > 3
# Out:
# False
