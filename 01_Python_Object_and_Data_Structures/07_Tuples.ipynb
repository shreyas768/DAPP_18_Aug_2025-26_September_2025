# %% [markdown]
# ### Constructing Tuples

# %%
#Create a Tuple
t = (1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
t1 = ('one',2,('hi','hello'), {'k1':'Shreyas'})

# %%
t1[-1]
# Out:
# {'k1': 'Shreyas'}

# %%
t1[1:]
# Out:
# (2, ('hi', 'hello'), {'k1': 'Shreyas'})

# %% [markdown]
# ##### Immutability

# %%
t1[0] = 'change'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t1[0] = 'change'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# ('one', 2, ('hi', 'hello'), {'k1': 'Shreyas'})

# %%
t1.append('two')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 t1.append('two')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 t1.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t1 = ('one',2,('hi','hello'), {'k1':'Shreyas'},'one',2,'one')

# %%
t1.count('one')
# Out:
# 3

# %%
t1.index(('hi','hello'))
# Out:
# 2
