# %%
my_list = [1,2,3]

# %%
type(my_list)
# Out:
# list

# %%
my_list1 = ['A string', 23, 100.9239, 'hi']

# %%
my_list1
# Out:
# ['A string', 23, 100.9239, 'hi']

# %%
len(my_list1)
# Out:
# 4

# %% [markdown]
# ###### Indexing and Slicing

# %%
my_list1
# Out:
# ['A string', 23, 100.9239, 'hi']

# %%
my_list1[0]
# Out:
# 'A string'

# %%
my_list1[-2]
# Out:
# 100.9239

# %%
type(my_list1[0])
# Out:
# str

# %%
type(my_list1[-2])
# Out:
# float

# %%
my_list1[0].upper()
# Out:
# 'A STRING'

# %%
my_list1[0].split()
# Out:
# ['A', 'string']

# %%
my_list1[-2]/34
# Out:
# 2.96835

# %%
my_list1
# Out:
# ['A string', 23, 100.9239, 'hi']

# %%
my_list1[1:]
# Out:
# [23, 100.9239, 'hi']

# %%
my_list1[1:3]
# Out:
# [23, 100.9239]

# %%
my_list1[-3:-1]
# Out:
# [23, 100.9239]

# %%
my_list1[1:-1]
# Out:
# [23, 100.9239]

# %%
my_list1[-3:3]
# Out:
# [23, 100.9239]

# %%
first_name = 'Shreyas'
last_name = 'Shukla'
course_name = 'DAPP course'

lst = [ 'this', 'is', 'I am', last_name, course_name, first_name , 'and', ' ']

# %%
print(lst[2]+lst[-1]+lst[-3]+lst[-1]+lst[-5]+lst[-1]+lst[-2]+lst[-1]+lst[-4])
# Out:
# I am Shreyas Shukla and DAPP course

# %% [markdown]
# ###### Concatenation of Lists

# %%
my_list1 + ['Bye','hello']
# Out:
# ['A string', 23, 100.9239, 'hi', 'Bye', 'hello']

# %%
my_list1
# Out:
# ['A string', 23, 100.9239, 'hi']

# %%
my_list1 = my_list1 + ['Bye','hello']

# %%
my_list1
# Out:
# ['A string', 23, 100.9239, 'hi', 'Bye', 'hello']

# %%
my_list1[2:-1] + [1,2,3,4]
# Out:
# [100.9239, 'hi', 'Bye', 1, 2, 3, 4]

# %%
my_list1*3
# Out:
# ['A string',
#  23,
#  100.9239,
#  'hi',
#  'Bye',
#  'hello',
#  'A string',
#  23,
#  100.9239,
#  'hi',
#  'Bye',
#  'hello',
#  'A string',
#  23,
#  100.9239,
#  'hi',
#  'Bye',
#  'hello']

# %% [markdown]
# ###### Basic List Methods

# %%
l1 = [11,22,33,44]

# %%
#Append : permanently add item to the end of the list
l1.append('append me !!')

# %%
l1
# Out:
# [11, 22, 33, 44, 'append me !!']

# %%
#pop : 'pop off' an item from the list. By default, it takes the last index

l1.pop()
# Out:
# 'append me !!'

# %%
l1
# Out:
# [11, 22, 33, 44]

# %%
l1.pop(2)
# Out:
# 33

# %%
l1
# Out:
# [11, 22, 44]

# %%
l2 = [101,102,103,104,'hello']

# %%
l2 = l2.append('something')

# %%
l2

# %%
type(l2)
# Out:
# NoneType

# %%
l2 = [101,102,103,104,'hello']

# %%
l2 = l2.pop()

# %%
l2
# Out:
# 'hello'

# %%
type(l2)
# Out:
# str

# %%
#reverse
num = [23,54,12,989,565,767,343,45]

# %%
num.reverse()

# %%
num
# Out:
# [45, 343, 767, 565, 989, 12, 54, 23]

# %%
#sort
num.sort()

# %%
num
# Out:
# [12, 23, 45, 54, 343, 565, 767, 989]

# %%
num.sort(reverse=True)

# %%
num
# Out:
# [989, 767, 565, 343, 54, 45, 23, 12]

# %%
#remove
l1 = ['hi',23,76,45,'hello',23,45,'world']

# %%
l1.remove('hi')

# %%
l1.remove(23)

# %%
l1
# Out:
# [76, 45, 'hello', 23, 45, 'world']

# %%
#index: return teh index of whatever element is placed as an argument

# %%
l1.index('hello')
# Out:
# 2

# %%
#insert
l1.insert(4,'bye')

# %%
l1
# Out:
# [76, 45, 'hello', 23, 'bye', 45, 'world']

# %%
#Extend
x=[1,2,3]
x.append([4,5])
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x=[1,2,3]
x.extend([4,5])
x
# Out:
# [1, 2, 3, 4, 5]

# %%
l1
# Out:
# [76, 45, 'hello', 23, 'bye', 45, 'world']

# %%
#count
l1.count(45)
# Out:
# 2

# %%
practice_list1 = [12.3,[45.6,['hello at IIT Roorkee']],'45',98,'iHUB',['Steve Jobs'], 'works', 32]

# %% [markdown]
# * 12.3+ 98
# * 'Steve Jobs works at iHUB
# * replace 32 by Shreyas
# * 'Hello Shreyas

# %%
#3
practice_list1[-1] = 'Shreyas'

# %%
practice_list1
# Out:
# [12.3,
#  [45.6, ['hello at IIT Roorkee']],
#  '45',
#  98,
#  'iHUB',
#  ['Steve Jobs'],
#  'works',
#  'Shreyas']

# %%
#4
practice_list1[1][1][0][:6].capitalize()+practice_list1[-1]
# Out:
# 'Hello Shreyas'

# %%
#1
practice_list1[0]+practice_list1[-5]
# Out:
# 110.3

# %%
#2
practice_list1[-3][0]+' '+practice_list1[-2]+practice_list1[1][1][0][5:9]+practice_list1[-4]
# Out:
# 'Steve Jobs works at iHUB'

# %%
practice_list2 = ['Gen AI', 'is the backbone of Earth']

# %% [markdown]
# * Add this string : 'Modern day' to practice_list2
# * 'Gen AI is the backbone of Modern day'

# %%
#1
practice_list2.append('Modern day')

# %%
practice_list2
# Out:
# ['Gen AI', 'is the backbone of Earth', 'Modern day']

# %%
#2
practice_list2[0]+ ' '+ practice_list2[-2][:-5]+practice_list2[-1]
# Out:
# 'Gen AI is the backbone of Modern day'

# %%
practice_list3 = [[98, [34.8,['hello world']], 'Elon', [['Musk'],'Shreyas']], 'controls', 505, 787]

# %% [markdown]
# * 'HELLO Elon Musk'
# * Do a division of any two numbers and multiply it with addition of the other numbers from practice_list3
# * replace 'Shreyas' with 'everyone'
# * 'Elon Musk controls everyone'

# %%
practice_list3[0]
# Out:
# [98, [34.8, ['hello world']], 'Elon', [['Musk'], 'Shreyas']]

# %%
#1
practice_list3[0][1][1][0][:6].upper()+practice_list3[0][-2]+' '+practice_list3[0][-1][0][0]
# Out:
# 'HELLO Elon Musk'

# %%
#2
(practice_list3[0][0]/practice_list3[0][1][0])*practice_list3[2]+practice_list3[3]
# Out:
# 2209.1264367816093

# %%
#3
practice_list3[0][-1][-1] = 'everyone'

# %%
#4
practice_list3[0][-2]+' '+practice_list3[0][-1][0][0]+' '+practice_list3[-3]+' '+practice_list3[0][-1][-1]
# Out:
# 'Elon Musk controls everyone'
