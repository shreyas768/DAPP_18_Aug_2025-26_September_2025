# %%
2
# Out:
# 2

# %%
type(2)
# Out:
# int

# %%
type('hello')
# Out:
# str

# %%
type(12.34)
# Out:
# float

# %% [markdown]
# ## Basic Arithmetic

# %%
#Addition
2+5
# Out:
# 7

# %%
#Subtraction 
5-3
# Out:
# 2

# %%
#multiplication 
6*8
# Out:
# 48

# %%
#Division
9/5
# Out:
# 1.8

# %%
#Floor Division
7//4
# Out:
# 1

# %%
7/4
# Out:
# 1.75

# %%
#Modulo
27%14
# Out:
# 13

# %%
#power
2**4
# Out:
# 16

# %%
2**0.5
# Out:
# 1.4142135623730951

# %%
#Order of Operations in Python

2+10*10+9
# Out:
# 111

# %%
(2+10)*(10+9) #Use parentheses to specify orders
# Out:
# 228

# %%
(2+(10*10))+9
# Out:
# 111

# %%
x367b = 2/1.5

# %%
x
# Out:
# 1.3333333333333333

# %%
y_z = 2/1.5+9732*1782-87281

# %%
y_z
# Out:
# 17255144.333333332
