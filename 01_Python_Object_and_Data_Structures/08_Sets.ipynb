# %%
d = {}

# %%
l = []

# %%
t = ()

# %%
type(d)
# Out:
# dict

# %%
type(l)
# Out:
# list

# %%
type(t)
# Out:
# tuple

# %%
s = set()

# %%
type(s)
# Out:
# set

# %%
#We add object to the set
s.add(1)

# %%
s
# Out:
# {1}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.add(1)

# %%
s
# Out:
# {1, 2}

# %%
s.add('1')

# %%
s
# Out:
# {1, '1', 2}

# %%
s.add('1')

# %%
s
# Out:
# {1, '1', 2}

# %%
l1 = [1,1,2,3,2,3,4,3,5,4,5,6,5,7,3,5,2,1,2,3,4,2,4,5,6,11,'hi',101,110]

# %%
#Cast as set to get unique values
set(l1)
# Out:
# {1, 101, 11, 110, 2, 3, 4, 5, 6, 7, 'hi'}
