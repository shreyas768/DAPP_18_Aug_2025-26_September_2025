# %%
a = 6

# %%
a
# Out:
# 6

# %%
type(a)
# Out:
# int

# %%
#add the objects

b = 9

# %%
a+b
# Out:
# 15

# %%
a+a
# Out:
# 12

# %%
#Reassignment
a = 13

# %%
a
# Out:
# 13

# %% [markdown]
# In Python, order of execution matters (not order of appearance)

# %%
a = a+a

# %%
a
# Out:
# 52

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a/3)
# Out:
# float

# %%
type(a/b)
# Out:
# float

# %% [markdown]
# your monthly income is 100 and you're paying 10% annually. Calculate total annual tax. You have to assign variables wherever possible

# %%
tax_rate_in_pct = 18
monthly_income = 240
annual_income = monthly_income*12

annual_tax = annual_income*(tax_rate_in_pct/100)

# %%
annual_tax
# Out:
# 518.4

# %% [markdown]
# Car covers 100 km in 6 hours. calculate its speed.  You have to assign variables wherever possible

# %%
dis = 140
time = 6

speed = dis/time

# %%
speed
# Out:
# 23.333333333333332

# %%
type(speed)
# Out:
# float

# %% [markdown]
# ###### Reassigning Variables

# %%
a
# Out:
# 10

# %%
a = a + 18

# %%
a
# Out:
# 28

# %%
a += 4 #same as a = a+ 4

# %%
a
# Out:
# 32

# %%
a *= 2 #same as a = a*2

# %%
a
# Out:
# 64

# %%
a -= 31 #same as a = a-31

# %%
a
# Out:
# 33

# %%
a /= 13 #same as a = a /13

# %%
a
# Out:
# 2.5384615384615383
